# %%
import geopandas as gpd
import numpy as np
import pandas as pd
from geodatasets import get_path
from sklearn import metrics, preprocessing
from sklearn.utils.estimator_checks import check_estimator

from gwlearn.ensemble import GWGradientBoostingClassifier, GWRandomForestClassifier
from gwlearn.linear_model import GWLogisticRegression
from gwlearn.search import BandwidthSearch

# %%
gdf = gpd.read_file(get_path("geoda.ncovr"))

# %%
gdf.shape
# Out:
# (3085, 70)

# %%
# It is in the geographic coords in the  US and we need to work with distances. Re-project and use only points as the graph builder will require points anyway.
gdf = gdf.set_geometry(gdf.representative_point()).to_crs(5070)

# %%
y = gdf["FH90"] > gdf["FH90"].median()

# %%
gwlr = GWLogisticRegression(
    geometry=gdf.geometry,
    bandwidth=900_000,
    fixed=True,
    n_jobs=-1,
    keep_models=True,
    max_iter=500,
)
# gwlr.fit(
#     pd.DataFrame(
#         preprocessing.scale(gdf.iloc[:, 9:15]), columns=gdf.iloc[:, 9:15].columns
#     ),
#     gdf["FH90"] > gdf["FH90"].median(),
# )

# %%
check_estimator(gwlr, on_fail='warn')
# Out:
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit_score_takes_y failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_overwrite_params failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_dont_overwrite_parameters failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_fit_returns_self failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_readonly_memmap_input failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_unfitted failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator should raise a NotFittedError when calling `predict` before fit. Either call `check_is_fitted(self)` at the beginning of `predict` or set `tags.requires_fit=False` on estimator tags to disable this check.
# - `check_is_fitted`: https://scikit-learn.org/dev/modules/generated/sklearn.utils.validation.check_is_fitted.html
# - Estimator Tags: https://scikit-learn.org/dev/developers/develop.html#estimator-tags
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_do_not_raise_errors_in_init_or_set_params failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: imbalance-learn is required for undersampling.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_n_features_in_after_fitting failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_mixin_order failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: GWLogisticRegression is inheriting from mixins in the wrong order. In general, in mixin inheritance, more specialized mixins must come before more general ones. This means, for instance, `BaseEstimator` should be on the right side of most other mixins. You need to change the order so that:
# ClassifierMixin comes before/left side of BaseEstimator
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_positive_only_tag_during_fit failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator 'GWLogisticRegression' raised ValueError unexpectedly. This happens when passing negative input values as X. If negative values are not supported for this estimator instance, then the tags.input_tags.positive_only tag needs to be set to True.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_dtypes failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_complex_data failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: The error message should contain one of the following patterns:
# Complex data not supported
# Got Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_dtype_object failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_empty_data_messages failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: The estimator GWLogisticRegression does not raise a ValueError when an empty data is used to train. Perhaps use check_array in train.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_pipeline_consistency failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_nan_inf failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator GWLogisticRegression doesn't check for NaN and inf in fit.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimator_sparse_tag failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator GWLogisticRegression raised an exception. The estimator failed when fitted on sparse data in accordance with its tag self.input_tags.sparse=False but didn't raise the appropriate error: error message should state explicitly that sparse input is not supported if this is not the case, e.g. by using check_array(X, accept_sparse=False).
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimator_sparse_array failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator GWLogisticRegression doesn't seem to fail gracefully on sparse data: error message should state explicitly that sparse input is not supported if this is not the case, e.g. by using check_array(X, accept_sparse=False).
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimator_sparse_matrix failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Estimator GWLogisticRegression doesn't seem to fail gracefully on sparse data: error message should state explicitly that sparse input is not supported if this is not the case, e.g. by using check_array(X, accept_sparse=False).
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_pickle failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_estimators_pickle failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_f_contiguous_array_estimator failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_methods_sample_order_invariance failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_methods_subset_invariance failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit2d_1sample failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit2d_1feature failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: The error message should contain one of the following patterns:
# 1 feature\(s\)
# n_features = 1
# n_features=1
# Got Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_dict_unchanged failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit_idempotent failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit_check_is_fitted failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_n_features_in failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: 'numpy.ndarray' object has no attribute 'values'
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit1d failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: tuple index out of range
#   warnings.warn(warning)
# /Users/martin/dev/pysal/gwlearn/.pixi/envs/default/lib/python3.13/site-packages/sklearn/utils/estimator_checks.py:896: EstimatorCheckFailedWarning: Test check_fit2d_predict1d failed for estimator GWLogisticRegression(bandwidth=900000, fixed=True,
#                      geometry=0          POINT (82379.611 2869738.377)
# 1       POINT (-1668934.975 3018181.842)
# 2       POINT (-1619958.935 3006537.453)
# 3         POINT (-1755117.16 3050487.11)
# 4       POINT (-1577383.387 2998650.582)
#                       ...
# 3080    POINT (-1657849.621 1282663.159)
# 3081    POINT (-1087856.066 1384868.843)
# 3082      POINT (1699672.63 1751264.588)
# 3083      POINT (1582459.36 1898177.771)
# 3084     POINT (-1155816.554 2564833.36)
# Name: geometry, Length: 3085, dtype: geometry,
#                      keep_models=True).
# Expected to fail reason: Not expected to fail
# Exception: Only binary dependent variable is supported.
#   warnings.warn(warning)
# [{'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_cloneable',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_cloneable',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_tags_renamed',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_valid_tag_types',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_repr',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_no_attributes_set_in_init',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit_score_takes_y',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_overwrite_params',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_dont_overwrite_parameters',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_fit_returns_self',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_readonly_memmap_input',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_unfitted',
#   'exception': AssertionError('Estimator should raise a NotFittedError when calling `predict` before fit. Either call `check_is_fitted(self)` at the beginning of `predict` or set `tags.requires_fit=False` on estimator tags to disable this check.\n- `check_is_fitted`: https://scikit-learn.org/dev/modules/generated/sklearn.utils.validation.check_is_fitted.html\n- Estimator Tags: https://scikit-learn.org/dev/developers/develop.html#estimator-tags'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_do_not_raise_errors_in_init_or_set_params',
#   'exception': ImportError('imbalance-learn is required for undersampling.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_n_features_in_after_fitting',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_mixin_order',
#   'exception': AssertionError('GWLogisticRegression is inheriting from mixins in the wrong order. In general, in mixin inheritance, more specialized mixins must come before more general ones. This means, for instance, `BaseEstimator` should be on the right side of most other mixins. You need to change the order so that:\nClassifierMixin comes before/left side of BaseEstimator'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_positive_only_tag_during_fit',
#   'exception': AssertionError("Estimator 'GWLogisticRegression' raised ValueError unexpectedly. This happens when passing negative input values as X. If negative values are not supported for this estimator instance, then the tags.input_tags.positive_only tag needs to be set to True."),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_dtypes',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
# ...
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_sparse_array',
#   'exception': AssertionError("Estimator GWLogisticRegression doesn't seem to fail gracefully on sparse data: error message should state explicitly that sparse input is not supported if this is not the case, e.g. by using check_array(X, accept_sparse=False)."),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimator_sparse_matrix',
#   'exception': AssertionError("Estimator GWLogisticRegression doesn't seem to fail gracefully on sparse data: error message should state explicitly that sparse input is not supported if this is not the case, e.g. by using check_array(X, accept_sparse=False)."),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_pickle',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_estimators_pickle',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_f_contiguous_array_estimator',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_parameters_default_constructible',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_methods_sample_order_invariance',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_methods_subset_invariance',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit2d_1sample',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit2d_1feature',
#   'exception': AssertionError('The error message should contain one of the following patterns:\n1 feature\\(s\\)\nn_features = 1\nn_features=1\nGot Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_get_params_invariance',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_set_params',
#   'exception': None,
#   'status': 'passed',
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_dict_unchanged',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit_idempotent',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit_check_is_fitted',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_n_features_in',
#   'exception': AttributeError("'numpy.ndarray' object has no attribute 'values'"),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit1d',
#   'exception': IndexError('tuple index out of range'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'},
#  {'estimator': GWLogisticRegression(bandwidth=900000, fixed=True,
#                        geometry=0          POINT (82379.611 2869738.377)
#   1       POINT (-1668934.975 3018181.842)
#   2       POINT (-1619958.935 3006537.453)
#   3         POINT (-1755117.16 3050487.11)
#   4       POINT (-1577383.387 2998650.582)
#                         ...
#   3080    POINT (-1657849.621 1282663.159)
#   3081    POINT (-1087856.066 1384868.843)
#   3082      POINT (1699672.63 1751264.588)
#   3083      POINT (1582459.36 1898177.771)
#   3084     POINT (-1155816.554 2564833.36)
#   Name: geometry, Length: 3085, dtype: geometry,
#                        keep_models=True),
#   'check_name': 'check_fit2d_predict1d',
#   'exception': ValueError('Only binary dependent variable is supported.'),
#   'expected_to_fail': False,
#   'expected_to_fail_reason': 'Check is not expected to fail',
#   'status': 'failed'}]

# %%
unique_values = set(np.unique(y))

# %%
unique_values
# Out:
# {np.False_, np.True_}

# %%
gwlr.feature_names_in_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 gwlr.feature_names_in_
#
# AttributeError: 'GWLogisticRegression' object has no attribute 'feature_names_in_'

# %%
gwlr.global_model.feature_names_in_
# Out:
# array(['HR60', 'HR70', 'HR80', 'HR90', 'HC60', 'HC70'], dtype=object)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=4,
                           n_informative=2, n_redundant=0,
                           random_state=0, shuffle=False)
clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf.fit(X, y)
clf.predict([[0, 0, 0, 0]])
clf.score(X, y)
# Out:
# 0.96

# %%
clf.feature_names_in_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 clf.feature_names_in_
#
# AttributeError: 'AdaBoostClassifier' object has no attribute 'feature_names_in_'
